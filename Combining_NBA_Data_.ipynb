# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
import io
df = pd.read_csv(io.BytesIO(uploaded['ROOKIES 2009 -2010 2 2.csv']))
df1 = pd.read_csv(io.BytesIO(uploaded['ROOKIES 2010 - 2011 2 2.csv']))
df2 = pd.read_csv(io.BytesIO(uploaded['ROOKIES 2011 -2011 2 2.csv']))
df3 = pd.read_csv(io.BytesIO(uploaded['ROOKIES 2012 -2013 2 2.csv']))
df4 = pd.read_csv(io.BytesIO(uploaded['ROOKIES 2013 -2014 3 2.csv']))
df5 = pd.read_csv(io.BytesIO(uploaded['ROOKIES 2014 -2015 2 2.csv']))
df6 = pd.read_csv(io.BytesIO(uploaded['ROOKIES 2015-2016 2 2.csv']))
df7 = pd.read_csv(io.BytesIO(uploaded['ROOKIES16-17.csv']))
df8 = pd.read_csv(io.BytesIO(uploaded['ROOKIES 2017-2018 2 2.csv']))
df9 = pd.read_csv(io.BytesIO(uploaded['ROOKIES 2018-2019 2 2.csv']))
df10 = pd.read_csv(io.BytesIO(uploaded['ROOKIES 2019-2020 2 2.csv']))
df11 = pd.read_csv(io.BytesIO(uploaded['ROOKIES 2020-2021 2.csv']))
df12 = pd.read_csv(io.BytesIO(uploaded['rookiesre2021-2022.csv']))
dfm = df.merge(df1, how='outer')
dfm  = dfm.merge(df2, how = 'outer')
dfm  = dfm.merge(df3, how = 'outer')
dfm  = dfm.merge(df4, how = 'outer')
dfm  = dfm.merge(df5, how = 'outer')
dfm  = dfm.merge(df6, how = 'outer')
dfm  = dfm.merge(df7, how = 'outer')
dfm  = dfm.merge(df8, how = 'outer')
dfm  = dfm.merge(df9, how = 'outer')
dfm  = dfm.merge(df10, how = 'outer')
dfm  = dfm.merge(df11, how = 'outer')
dfm  = dfm.merge(df12, how = 'outer')
dfm
# Out:
#      <input type="file" id="files-c8dc9fd4-9a53-4e7c-b8a1-dffc1d9dfc81" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c8dc9fd4-9a53-4e7c-b8a1-dffc1d9dfc81">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pd.set_option('display.max_columns', None, 'display.max_rows', None )
dfm
# Out:
#                        PLAYER TEAM  AGE  GP   W   L   MIN   PTS  FGM   FGA  \
# 0                Tyreke Evans  SAC   20  72  23  49  37.2  20.1  7.4  16.2
# 1               Stephen Curry  GSW   22  80  25  55  36.2  17.5  6.6  14.3
# 2            Brandon Jennings  MIL   20  82  46  36  32.6  15.5  5.5  14.8
# 3             Reggie Williams  GSW   23  24   9  15  32.6  15.2  5.8  11.8
# 4             Marcus Thornton  NOH   23  73  33  40  25.6  14.5  5.5  12.1
# 5                 Jonny Flynn  MIN   21  81  15  66  28.9  13.5  4.9  11.8
# 6             Darren Collison  NOH   22  76  34  42  27.8  12.4  4.9  10.4
# 7                 Omri Casspi  SAC   22  77  24  53  25.1  10.3  3.9   8.7
# 8                James Harden  OKC   20  76  47  29  22.9   9.9  3.1   7.6
# 9             Wesley Matthews  UTA   23  82  53  29  24.7   9.4  3.3   6.9
# 10              Jonas Jerebko  DET   23  80  26  54  27.9   9.3  3.6   7.5
# ...
